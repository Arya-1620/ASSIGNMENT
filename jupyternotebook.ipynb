# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Arya Girish K

# %% [markdown]
# Data Scientist

# %% [markdown]
# I am interested in data science because I loved to explore various insights by working with data.

# %% [markdown]
# ### addition

# %%
1+1+2
# Out:
# 4

# %% [markdown]
# |Words|numeric|
# |-----|-------|
# |one|1|
# |two|2|
# |three|3|

# %% [markdown]
# - one
# - two
# - three

# %% [markdown]
# 1. one
# 2. two
# 3. three
